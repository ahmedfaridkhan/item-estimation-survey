# %%
import pandas as pd

survey_df = pd.read_csv('https://raw.githubusercontent.com/ahmedfaridkhan/item-estimation-survey/main/BA-830-Survey_results.csv', skiprows=[1, 2], header=0)

# %%
survey_df
# Out:
#                StartDate              EndDate      Status        IPAddress  \
# 0    2024-02-25 16:51:25  2024-02-25 16:51:49  IP Address   128.197.29.250
# 1    2024-02-25 16:51:37  2024-02-25 16:51:51  IP Address     104.28.39.33
# 2    2024-02-25 16:51:05  2024-02-25 16:51:08  IP Address     73.114.90.18
# 3    2024-02-25 16:51:50  2024-02-25 16:52:14  IP Address     73.114.90.18
# 4    2024-02-25 16:54:06  2024-02-25 16:54:16  IP Address    104.28.39.129
# ..                   ...                  ...         ...              ...
# 227  2024-03-01 11:31:49  2024-03-01 11:38:56  IP Address   177.11.210.150
# 228  2024-03-01 12:49:04  2024-03-01 12:52:55  IP Address      42.2.71.129
# 229  2024-03-01 14:41:06  2024-03-01 14:45:38  IP Address  186.222.199.176
# 230  2024-03-01 14:40:58  2024-03-01 14:50:24  IP Address  186.222.199.176
# 231  2024-03-01 14:50:33  2024-03-01 15:00:47  IP Address  186.222.199.176
#
#      Progress  Duration (in seconds)  Finished         RecordedDate  \
# 0          25                     23     False  2024-02-27 13:17:06
# 1          40                     14     False  2024-02-27 13:17:06
# 2          15                      2     False  2024-02-27 13:17:06
# 3          30                     23     False  2024-02-27 13:17:06
# 4          30                      9     False  2024-02-27 13:17:06
# ..        ...                    ...       ...                  ...
# 227       100                    427      True  2024-03-01 11:38:57
# 228       100                    230      True  2024-03-01 12:52:55
# 229       100                    272      True  2024-03-01 14:45:39
# 230       100                    565      True  2024-03-01 14:50:24
# 231       100                    614      True  2024-03-01 15:00:48
#
#             ResponseId  RecipientLastName  ...  treatment 2      control  \
# 0    R_1p77grDRCEMPuUh                NaN  ...         24.0          NaN
# 1    R_10TP6Y7vnC7qWyZ                NaN  ...          NaN  Lars Halden
# 2    R_5duQQMZiY4URHTj                NaN  ...          NaN          NaN
# 3    R_539imJmHt0BG62t                NaN  ...         10.0          NaN
# 4    R_1VfhtThagGFH9L3                NaN  ...          NaN  Lars Halden
# ..                 ...                ...  ...          ...          ...
# 227  R_1Kr0GH77bU5uEhj                NaN  ...          NaN  Lars Halden
# 228  R_45H1UOypvrAkbhP                NaN  ...          NaN  Lars Halden
# 229  R_3WV43T8U5W9B2RX                NaN  ...        102.0          NaN
# 230  R_3KEtzYKw0rPXeX7                NaN  ...        102.0          NaN
# 231  R_5JxXoGHsabr7eYF                NaN  ...        102.0          NaN
#
#        Q1     Q2     Q3     Q4      Q5   Q6                     Gender   Age
# 0     NaN    NaN    NaN    NaN     NaN  NaN                        NaN   NaN
# 1    14.0    NaN    NaN    NaN     NaN  NaN                        NaN   NaN
# 2     NaN    NaN    NaN    NaN     NaN  NaN                        NaN   NaN
# 3     NaN    NaN    NaN    NaN     NaN  NaN                        NaN   NaN
# 4     NaN    NaN    NaN    NaN     NaN  NaN                        NaN   NaN
# ..    ...    ...    ...    ...     ...  ...                        ...   ...
# 227   2.0  100.0  150.0  120.0   400.0  250                       Male  42.0
# 228  13.0  200.0  150.0  120.0   500.0  250  Non-binary / third gender  35.0
# 229  10.0   50.0   90.0   55.0   220.0   80                     Female  16.0
# 230  12.0  150.0  208.0   92.0  2400.0  100                     Female  67.0
# 231  12.0  328.0  350.0  130.0   450.0  120                       Male  20.0
#
# [232 rows x 28 columns]

# %%
survey_df.columns
# Out:
# Index(['StartDate', 'EndDate', 'Status', 'IPAddress', 'Progress',
#        'Duration (in seconds)', 'Finished', 'RecordedDate', 'ResponseId',
#        'RecipientLastName', 'RecipientFirstName', 'RecipientEmail',
#        'ExternalReference', 'LocationLatitude', 'LocationLongitude',
#        'DistributionChannel', 'UserLanguage', 'treatment 1', 'treatment 2',
#        'control', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Gender', 'Age'],
#       dtype='object')

# %%
survey_df = survey_df.drop(['StartDate', 'EndDate', 'Status', 'Duration (in seconds)', 'RecordedDate', 'ResponseId', 'RecipientLastName', 'RecipientFirstName',\
       'RecipientEmail', 'ExternalReference', 'LocationLatitude', 'LocationLongitude', 'DistributionChannel', 'UserLanguage'], axis = 1)

# %%
survey_df
# Out:
#            IPAddress  Progress  Finished  treatment 1  treatment 2  \
# 0     128.197.29.250        25     False          NaN         24.0
# 1       104.28.39.33        40     False          NaN          NaN
# 2       73.114.90.18        15     False          NaN          NaN
# 3       73.114.90.18        30     False          NaN         10.0
# 4      104.28.39.129        30     False          NaN          NaN
# ..               ...       ...       ...          ...          ...
# 227   177.11.210.150       100      True          NaN          NaN
# 228      42.2.71.129       100      True          NaN          NaN
# 229  186.222.199.176       100      True          NaN        102.0
# 230  186.222.199.176       100      True          NaN        102.0
# 231  186.222.199.176       100      True          NaN        102.0
#
#          control    Q1     Q2     Q3     Q4      Q5   Q6  \
# 0            NaN   NaN    NaN    NaN    NaN     NaN  NaN
# 1    Lars Halden  14.0    NaN    NaN    NaN     NaN  NaN
# 2            NaN   NaN    NaN    NaN    NaN     NaN  NaN
# 3            NaN   NaN    NaN    NaN    NaN     NaN  NaN
# 4    Lars Halden   NaN    NaN    NaN    NaN     NaN  NaN
# ..           ...   ...    ...    ...    ...     ...  ...
# 227  Lars Halden   2.0  100.0  150.0  120.0   400.0  250
# 228  Lars Halden  13.0  200.0  150.0  120.0   500.0  250
# 229          NaN  10.0   50.0   90.0   55.0   220.0   80
# 230          NaN  12.0  150.0  208.0   92.0  2400.0  100
# 231          NaN  12.0  328.0  350.0  130.0   450.0  120
#
#                         Gender   Age
# 0                          NaN   NaN
# 1                          NaN   NaN
# 2                          NaN   NaN
# 3                          NaN   NaN
# 4                          NaN   NaN
# ..                         ...   ...
# 227                       Male  42.0
# 228  Non-binary / third gender  35.0
# 229                     Female  16.0
# 230                     Female  67.0
# 231                       Male  20.0
#
# [232 rows x 14 columns]

# %%
survey_df.Progress.hist()
# Out:
# <Axes: >

# %%
survey_df.Progress.value_counts()
# Out:
# 100    219
# 15       4
# 30       3
# 25       1
# 40       1
# 0        1
# 50       1
# 33       1
# 90       1
# Name: Progress, dtype: int64

# %%
survey_df.Finished.value_counts()
# Out:
# True     219
# False     13
# Name: Finished, dtype: int64

# %%
survey_df = survey_df[survey_df['Finished'] == True]

# %%
survey_df = survey_df.reset_index(drop=True)

# %%
survey_df
# Out:
#            IPAddress  Progress  Finished  treatment 1  treatment 2  \
# 0       77.164.41.88       100      True          9.0          NaN
# 1    172.225.170.111       100      True          NaN        102.0
# 2     190.111.246.27       100      True          NaN        102.0
# 3     67.205.195.178       100      True          NaN          NaN
# 4      172.58.134.27       100      True          NaN          NaN
# ..               ...       ...       ...          ...          ...
# 214   177.11.210.150       100      True          NaN          NaN
# 215      42.2.71.129       100      True          NaN          NaN
# 216  186.222.199.176       100      True          NaN        102.0
# 217  186.222.199.176       100      True          NaN        102.0
# 218  186.222.199.176       100      True          NaN        102.0
#
#              control    Q1     Q2     Q3     Q4      Q5    Q6  \
# 0                NaN  11.0  160.0  180.0   60.0   280.0   180
# 1                NaN  20.0  100.0   70.0   40.0   200.0   150
# 2                NaN  10.0  300.0  140.0   50.0   550.0   350
# 3    Ingrid Johansen  10.0  500.0  180.0   90.0   350.0  1200
# 4        Lars Halden  10.0  100.0  120.0   40.0   800.0    90
# ..               ...   ...    ...    ...    ...     ...   ...
# 214      Lars Halden   2.0  100.0  150.0  120.0   400.0   250
# 215      Lars Halden  13.0  200.0  150.0  120.0   500.0   250
# 216              NaN  10.0   50.0   90.0   55.0   220.0    80
# 217              NaN  12.0  150.0  208.0   92.0  2400.0   100
# 218              NaN  12.0  328.0  350.0  130.0   450.0   120
#
#                         Gender   Age
# 0                       Female  22.0
# 1                         Male  30.0
# 2                       Female  26.0
# 3                         Male  53.0
# 4                       Female  23.0
# ..                         ...   ...
# 214                       Male  42.0
# 215  Non-binary / third gender  35.0
# 216                     Female  16.0
# 217                     Female  67.0
# 218                       Male  20.0
#
# [219 rows x 14 columns]

# %%
len(survey_df)
# Out:
# 219

# %%
import numpy as np

survey_df['group'] = 'control'  # Set a default value for the 'group' column

for value in range(len(survey_df)):
    if pd.isna(survey_df['treatment 1'].iloc[value]) and pd.isna(survey_df['treatment 2'].iloc[value]):
        survey_df['group'].iloc[value] = 'control'
    elif pd.isna(survey_df['control'].iloc[value]) and pd.isna(survey_df['treatment 2'].iloc[value]):
        survey_df['group'].iloc[value] = 'treatment 1'
    else:
        survey_df['group'].iloc[value] = 'treatment 2'
# Out:
# <ipython-input-19-c6d2a29007b0>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_df['group'].iloc[value] = 'treatment 1'
# <ipython-input-19-c6d2a29007b0>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_df['group'].iloc[value] = 'treatment 2'
# <ipython-input-19-c6d2a29007b0>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_df['group'].iloc[value] = 'control'

# %%
survey_df
# Out:
#            IPAddress  Progress  Finished  treatment 1  treatment 2  \
# 0       77.164.41.88       100      True          9.0          NaN
# 1    172.225.170.111       100      True          NaN        102.0
# 2     190.111.246.27       100      True          NaN        102.0
# 3     67.205.195.178       100      True          NaN          NaN
# 4      172.58.134.27       100      True          NaN          NaN
# ..               ...       ...       ...          ...          ...
# 214   177.11.210.150       100      True          NaN          NaN
# 215      42.2.71.129       100      True          NaN          NaN
# 216  186.222.199.176       100      True          NaN        102.0
# 217  186.222.199.176       100      True          NaN        102.0
# 218  186.222.199.176       100      True          NaN        102.0
#
#              control    Q1     Q2     Q3     Q4      Q5    Q6  \
# 0                NaN  11.0  160.0  180.0   60.0   280.0   180
# 1                NaN  20.0  100.0   70.0   40.0   200.0   150
# 2                NaN  10.0  300.0  140.0   50.0   550.0   350
# 3    Ingrid Johansen  10.0  500.0  180.0   90.0   350.0  1200
# 4        Lars Halden  10.0  100.0  120.0   40.0   800.0    90
# ..               ...   ...    ...    ...    ...     ...   ...
# 214      Lars Halden   2.0  100.0  150.0  120.0   400.0   250
# 215      Lars Halden  13.0  200.0  150.0  120.0   500.0   250
# 216              NaN  10.0   50.0   90.0   55.0   220.0    80
# 217              NaN  12.0  150.0  208.0   92.0  2400.0   100
# 218              NaN  12.0  328.0  350.0  130.0   450.0   120
#
#                         Gender   Age        group
# 0                       Female  22.0  treatment 1
# 1                         Male  30.0  treatment 2
# 2                       Female  26.0  treatment 2
# 3                         Male  53.0      control
# 4                       Female  23.0      control
# ..                         ...   ...          ...
# 214                       Male  42.0      control
# 215  Non-binary / third gender  35.0      control
# 216                     Female  16.0  treatment 2
# 217                     Female  67.0  treatment 2
# 218                       Male  20.0  treatment 2
#
# [219 rows x 15 columns]

# %%
survey_df = survey_df.drop(['Progress', 'Finished', 'treatment 1', 'treatment 2', 'control'], axis = 1)

# %%
survey_df
# Out:
#            IPAddress    Q1     Q2     Q3     Q4      Q5    Q6  \
# 0       77.164.41.88  11.0  160.0  180.0   60.0   280.0   180
# 1    172.225.170.111  20.0  100.0   70.0   40.0   200.0   150
# 2     190.111.246.27  10.0  300.0  140.0   50.0   550.0   350
# 3     67.205.195.178  10.0  500.0  180.0   90.0   350.0  1200
# 4      172.58.134.27  10.0  100.0  120.0   40.0   800.0    90
# ..               ...   ...    ...    ...    ...     ...   ...
# 214   177.11.210.150   2.0  100.0  150.0  120.0   400.0   250
# 215      42.2.71.129  13.0  200.0  150.0  120.0   500.0   250
# 216  186.222.199.176  10.0   50.0   90.0   55.0   220.0    80
# 217  186.222.199.176  12.0  150.0  208.0   92.0  2400.0   100
# 218  186.222.199.176  12.0  328.0  350.0  130.0   450.0   120
#
#                         Gender   Age        group
# 0                       Female  22.0  treatment 1
# 1                         Male  30.0  treatment 2
# 2                       Female  26.0  treatment 2
# 3                         Male  53.0      control
# 4                       Female  23.0      control
# ..                         ...   ...          ...
# 214                       Male  42.0      control
# 215  Non-binary / third gender  35.0      control
# 216                     Female  16.0  treatment 2
# 217                     Female  67.0  treatment 2
# 218                       Male  20.0  treatment 2
#
# [219 rows x 10 columns]

# %%
survey_df.group.value_counts()
# Out:
# treatment 2    81
# control        80
# treatment 1    58
# Name: group, dtype: int64

# %%
survey_df = survey_df.drop_duplicates(subset = ['IPAddress'], keep = 'first')

# %%
survey_df
# Out:
#            IPAddress    Q1     Q2     Q3     Q4     Q5    Q6  \
# 0       77.164.41.88  11.0  160.0  180.0   60.0  280.0   180
# 1    172.225.170.111  20.0  100.0   70.0   40.0  200.0   150
# 2     190.111.246.27  10.0  300.0  140.0   50.0  550.0   350
# 3     67.205.195.178  10.0  500.0  180.0   90.0  350.0  1200
# 4      172.58.134.27  10.0  100.0  120.0   40.0  800.0    90
# ..               ...   ...    ...    ...    ...    ...   ...
# 208     66.38.95.243  10.0  200.0  100.0   40.0  190.0    70
# 209  187.181.204.234   9.0  250.0  100.0   90.0  500.0    70
# 212  188.250.141.239  10.0  250.0  120.0   75.0  200.0   240
# 214   177.11.210.150   2.0  100.0  150.0  120.0  400.0   250
# 215      42.2.71.129  13.0  200.0  150.0  120.0  500.0   250
#
#                         Gender   Age        group
# 0                       Female  22.0  treatment 1
# 1                         Male  30.0  treatment 2
# 2                       Female  26.0  treatment 2
# 3                         Male  53.0      control
# 4                       Female  23.0      control
# ..                         ...   ...          ...
# 208                     Female  22.0  treatment 1
# 209                     Female  51.0  treatment 1
# 212                     Female  36.0      control
# 214                       Male  42.0      control
# 215  Non-binary / third gender  35.0      control
#
# [192 rows x 10 columns]

# %%
# Define the path and name of the CSV file you want to create
csv_file_path = '/content/sample_data/my_dataframe.csv'

# Export the DataFrame to a CSV file
survey_df.to_csv(csv_file_path, index=False)

# %%
long_df = pd.melt(survey_df, id_vars=['IPAddress', 'Gender', 'Age', 'group'],
                  value_vars=['Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6'],
                  var_name='Question', value_name='Estimate')
